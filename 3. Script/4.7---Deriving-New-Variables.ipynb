# %% [markdown]
# # 4.7 Practice - Deriving New Variables

# %% [markdown]
# #### Import libraries and data

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# declare path as variable

path = r'/Users/dekstrom/Documents/Career Foundry/Instacart Basket Analysis 11-2023'

# %%
# import ords_prods_merge_revised.pkl

ords_prods_merge = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_revised.pkl'))

# %% [markdown]
# #### If-Statements with User-Defined Functions

# %%
# create smaller subset of data

df = ords_prods_merge[:1000000]

# %%
# function for categorizing prices

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# create new column with price_label output

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/8w/2xbh8c1d2qnd_6yc30_xs1cw0000gp/T/ipykernel_78522/310196210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# return value counts of price_range

df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# return max value of prices

df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# #### If-Statements with the loc() Function

# %%
# create high range label

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/8w/2xbh8c1d2qnd_6yc30_xs1cw0000gp/T/ipykernel_78522/2964027337.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# /var/folders/8w/2xbh8c1d2qnd_6yc30_xs1cw0000gp/T/ipykernel_78522/2964027337.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# create med range label

df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# create low range label

df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# return value counts of price_range_loc

df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# create high range label on full ords_prods_merge

ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/8w/2xbh8c1d2qnd_6yc30_xs1cw0000gp/T/ipykernel_78522/3248249601.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# create med range label on full ords_prods_merge

ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# create low range label on full ords_prods_merge

ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# return value counts of price_range_loc

ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21867446
# Low-range product     10126321
# High-range product      412551
# Name: count, dtype: int64

# %%
# check output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# #### If-Statements with For-Loops

# %%
# example

for x in range(30,45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
# frequency of orders_day_of_week column

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204438
# 1    5660482
# 6    4496693
# 2    4214018
# 5    4205990
# 3    3840722
# 4    3783975
# Name: count, dtype: int64

# %%
# assign busy-ness label based on orders_day_of_week

result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# check output

result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# add result to ords_prods_merge as a new column

ords_prods_merge['busiest_day'] = result

# %%
# check value count of new column

ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22417905
# Busiest day        6204438
# Least busy         3783975
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# # 4.7 Task

# %% [markdown]
# #### Question 2
#
# Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# check which days are busiest

ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204438
# 1    5660482
# 6    4496693
# 2    4214018
# 5    4205990
# 3    3840722
# 4    3783975
# Name: count, dtype: int64

# %%
# create label for busiest days

ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([0, 1]), 'busiest_days'] = 'Busiest Days'
# Out:
# /var/folders/8w/2xbh8c1d2qnd_6yc30_xs1cw0000gp/T/ipykernel_78522/1328444396.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Busiest Days' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([0, 1]), 'busiest_days'] = 'Busiest Days'

# %%
# create label for regular days

ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([6, 2, 5]), 'busiest_days'] = 'Regularly busy Days'

# %%
# create label for slowest days

ords_prods_merge.loc[ords_prods_merge['orders_day_of_week'].isin([3, 4]), 'busiest_days'] = 'Slowest Days'

# %% [markdown]
# #### Question 3
#
# Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# check value counts for busiest_days

ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy Days    12916701
# Busiest Days           11864920
# Slowest Days            7624697
# Name: count, dtype: int64

# %%
# check value counts for busiest_day to compare with busiest_days

ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22417905
# Busiest day        6204438
# Least busy         3783975
# Name: count, dtype: int64

# %%
# confirm total number of counts are equal for both new columns

ords_prods_merge['busiest_day'].shape == ords_prods_merge['busiest_days'].shape
# Out:
# True

# %%
ords_prods_merge['busiest_day'].shape
# Out:
# (32406318,)

# %%
# check output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# ##### Question 3 Answers
#
# As we might expect, the busiest_days value counts are much closer together than the busiest_day value counts because we are now grouping the days in groups of 2 or 3 days as opposed 1 or 5 days. We also see that the total counts are equal for both as we would expect.

# %% [markdown]
# #### Question 4
#
# When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# create list of hours sorted by value count

hours_sorted = ords_prods_merge['order_hour_of_day'].value_counts(dropna = False).index.to_numpy()

# %%
# create empty list and for-loop to populate list with busiest time of day labels

busiest_hour = []

for row in ords_prods_merge['order_hour_of_day']:
    if row in hours_sorted[:8]:
        busiest_hour.append("Most orders")
    elif row in hours_sorted[8:16]:
        busiest_hour.append("Average orders")
    else:
        busiest_hour.append("Fewest orders")

# %%
# create column in dataframe equal to busiest_hour

ords_prods_merge['busiest_period_of_day'] = busiest_hour

# %%
# check output

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# #### Question 5
#
# Print the frequency for this new column.

# %%
# check frequency of busiest_period_of_day

ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118994
# Average orders     9998079
# Fewest orders      1289245
# Name: count, dtype: int64

# %% [markdown]
# #### Question 7
#
# Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
# export to pickle file

ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_derived.pkl'))
